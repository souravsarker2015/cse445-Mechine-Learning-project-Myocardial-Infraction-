# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as splt
import seaborn
import seaborn as sns
import matplotlib
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-383a167b-2803-43e6-8a49-675db7cb4095" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-383a167b-2803-43e6-8a49-675db7cb4095">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data1.csv to data1.csv

# %%
df=pd.read_csv('data1.csv')

# %%
df
# Out:
#         Sex  Age   Profession  ... symptoms-duration diabetes-mellitus  Chest Pain
# 0      Male   35  Businessman  ...               NaN                No          No
# 1      Male   60      Retired  ...               NaN               NaN         Yes
# 2      Male   37     Engineer  ...               NaN               NaN         Yes
# 3      Male   29         govt  ...               NaN               NaN         Yes
# 4    Female   35    Housewife  ...               NaN               NaN          No
# ..      ...  ...          ...  ...               ...               ...         ...
# 340  Female   55    housewife  ...               NaN               yes          No
# 341  Female   65     business  ...               NaN               yes          No
# 342    Male   53      teacher  ...               NaN               yes         Yes
# 343  Female   45    housewife  ...               NaN               yes          No
# ...

# %%
df['Chest Pain'].value_counts()
# Out:
# Yes    226
# No      87
# Name: Chest Pain, dtype: int64

# %%
seaborn.countplot(df['Chest Pain'])

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isna().sum()
# Out:
# Sex                                   0
# Age                                   0
# Profession                           28
# Marital Status                      195
# Height                              179
# Weight(kgs)                           5
# Breathing Problem                     4
# Stress                               21
# Work Load                            14
# Food Habit                           25
# heart-rate(bpm)                      29
# systolic(mmHg)                       20
# diastolic(mmHg)                      24
# blood-sugar-before-meal(mmol/L)      23
# blood-sugar-after-meal(mmol/L)       11
# urine-color-before-meal              28
# urine-color-after-meal               29
# drug-history                         18
# physical-activity                    46
# smoking(per day)                     25
# headache-for-high-blood-pressure    224
# weakness                             37
# symptoms-duration                   345
# ...

# %%
# # drop unnecessary columns
# cols = ['headache-for-high-blood-pressure', 'symptoms-duration']
# df = df.drop(columns=cols, axis=1)
# df.head()

# %%
df
# Out:
#         Sex  Age   Profession  ... symptoms-duration diabetes-mellitus  Chest Pain
# 0      Male   35  Businessman  ...               NaN                No          No
# 1      Male   60      Retired  ...               NaN               NaN         Yes
# 2      Male   37     Engineer  ...               NaN               NaN         Yes
# 3      Male   29         govt  ...               NaN               NaN         Yes
# 4    Female   35    Housewife  ...               NaN               NaN          No
# ..      ...  ...          ...  ...               ...               ...         ...
# 340  Female   55    housewife  ...               NaN               yes          No
# 341  Female   65     business  ...               NaN               yes          No
# 342    Male   53      teacher  ...               NaN               yes         Yes
# 343  Female   45    housewife  ...               NaN               yes          No
# ...

# %%
#df['urine-color-before-meal'].mode()

# %%
#Mean

df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Weight(kgs)'] = df['Weight(kgs)'].fillna(df['Weight(kgs)'].mean())
df['heart-rate(bpm)'] = df['heart-rate(bpm)'].fillna(df['heart-rate(bpm)'].mean())
df['systolic(mmHg)'] = df['systolic(mmHg)'].fillna(df['systolic(mmHg)'].mean())
df['diastolic(mmHg)'] = df['diastolic(mmHg)'].fillna(df['diastolic(mmHg)'].mean())
df['blood-sugar-before-meal(mmol/L)'] = df['blood-sugar-before-meal(mmol/L)'].fillna(df['blood-sugar-before-meal(mmol/L)'].mean())
df['blood-sugar-after-meal(mmol/L)'] = df['blood-sugar-after-meal(mmol/L)'].fillna(df['blood-sugar-after-meal(mmol/L)'].mean())

# %%
#mode

df['Sex'] = df["Sex"].fillna(df['Sex'].mode()[0])   

df['Profession'] = df["Profession"].fillna(df['Profession'].mode()[0])
df['Marital Status'] = df["Marital Status"].fillna(df['Marital Status'].mode()[0])
df['Height'] = df["Height"].fillna(df['Height'].mode()[0])
df['Breathing Problem'] = df["Breathing Problem"].fillna(df['Breathing Problem'].mode()[0])
df['Stress'] = df["Stress"].fillna(df['Stress'].mode()[0])
df['Work Load'] = df["Work Load"].fillna(df['Work Load'].mode()[0])
df['Food Habit'] = df["Food Habit"].fillna(df['Food Habit'].mode()[0])

df['urine-color-before-meal'] = df["urine-color-before-meal"].fillna(df['urine-color-before-meal'].mode()[0])
df['urine-color-after-meal'] = df["urine-color-after-meal"].fillna(df['urine-color-after-meal'].mode()[0])
df['drug-history'] = df["drug-history"].fillna(df['drug-history'].mode()[0])
df['physical-activity'] = df["physical-activity"].fillna(df['physical-activity'].mode()[0])

df['smoking(per day)'] = df["smoking(per day)"].fillna(df['smoking(per day)'].mode()[0])
df['headache-for-high-blood-pressure'] = df["headache-for-high-blood-pressure"].fillna(df['headache-for-high-blood-pressure'].mode()[0])
df['weakness'] = df["weakness"].fillna(df['weakness'].mode()[0])
df['diabetes-mellitus'] = df["diabetes-mellitus"].fillna(df['diabetes-mellitus'].mode()[0])
df['Chest Pain'] = df["Chest Pain"].fillna(df['Chest Pain'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Sex                                   0
# Age                                   0
# Profession                            0
# Marital Status                        0
# Height                                0
# Weight(kgs)                           0
# Breathing Problem                     0
# Stress                                0
# Work Load                             0
# Food Habit                            0
# heart-rate(bpm)                       0
# systolic(mmHg)                        0
# diastolic(mmHg)                       0
# blood-sugar-before-meal(mmol/L)       0
# blood-sugar-after-meal(mmol/L)        0
# urine-color-before-meal               0
# urine-color-after-meal                0
# drug-history                          0
# physical-activity                     0
# smoking(per day)                      0
# headache-for-high-blood-pressure      0
# weakness                              0
# symptoms-duration                   345
# ...

# %%
df=df.drop('symptoms-duration',axis=1)

# %%
df
# Out:
#         Sex  Age   Profession  ... weakness diabetes-mellitus  Chest Pain
# 0      Male   35  Businessman  ...      Yes                No          No
# 1      Male   60      Retired  ...      yes               yes         Yes
# 2      Male   37     Engineer  ...      yes               yes         Yes
# 3      Male   29         govt  ...      Yes               yes         Yes
# 4    Female   35    Housewife  ...      yes               yes          No
# ..      ...  ...          ...  ...      ...               ...         ...
# 340  Female   55    housewife  ...      yes               yes          No
# 341  Female   65     business  ...      yes               yes          No
# 342    Male   53      teacher  ...      yes               yes         Yes
# 343  Female   45    housewife  ...      yes               yes          No
# 344    Male   55      teacher  ...      yes               yes         Yes
#
# [345 rows x 24 columns]

# %%
df.describe()
# Out:
#               Age  ...  smoking(per day)
# count  345.000000  ...        345.000000
# mean    45.284058  ...          2.518841
# std     14.799647  ...          3.334164
# min     14.000000  ...          0.000000
# 25%     34.000000  ...          0.000000
# 50%     47.000000  ...          0.000000
# 75%     55.000000  ...          5.000000
# max     86.000000  ...         12.000000
#
# [8 rows x 8 columns]

# %%
# corr = df.corr()
# splt.figure(figsize=(15,10))
# sns.heatmap(corr, annot = True, cmap="BuPu")

# %%
seaborn.countplot(df['Sex'])

# %%
seaborn.countplot(df['Chest Pain'])

# %%
seaborn.countplot(x='Sex',hue='Chest Pain',data=df,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))

# %%
seaborn.countplot(x='Age',hue='Chest Pain',data=df,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))

# %%
df
# Out:
#         Sex  Age   Profession  ... weakness diabetes-mellitus  Chest Pain
# 0      Male   35  Businessman  ...      Yes                No          No
# 1      Male   60      Retired  ...      yes               yes         Yes
# 2      Male   37     Engineer  ...      yes               yes         Yes
# 3      Male   29         govt  ...      Yes               yes         Yes
# 4    Female   35    Housewife  ...      yes               yes          No
# ..      ...  ...          ...  ...      ...               ...         ...
# 340  Female   55    housewife  ...      yes               yes          No
# 341  Female   65     business  ...      yes               yes          No
# 342    Male   53      teacher  ...      yes               yes         Yes
# 343  Female   45    housewife  ...      yes               yes          No
# 344    Male   55      teacher  ...      yes               yes         Yes
#
# [345 rows x 24 columns]

# %%
# df=df.drop('Sex',axis=1)

# %%
#df

# %%
df.describe()
# Out:
#               Age  ...  smoking(per day)
# count  345.000000  ...        345.000000
# mean    45.284058  ...          2.518841
# std     14.799647  ...          3.334164
# min     14.000000  ...          0.000000
# 25%     34.000000  ...          0.000000
# 50%     47.000000  ...          0.000000
# 75%     55.000000  ...          5.000000
# max     86.000000  ...         12.000000
#
# [8 rows x 8 columns]

# %%
df.corr()
# Out:
#                                       Age  ...  smoking(per day)
# Age                              1.000000  ...         -0.022849
# Weight(kgs)                     -0.029524  ...          0.206530
# heart-rate(bpm)                 -0.072393  ...          0.074330
# systolic(mmHg)                   0.281898  ...         -0.005893
# diastolic(mmHg)                  0.175415  ...          0.002916
# blood-sugar-before-meal(mmol/L)  0.261526  ...          0.004158
# blood-sugar-after-meal(mmol/L)   0.222589  ...         -0.052109
# smoking(per day)                -0.022849  ...          1.000000
#
# [8 rows x 8 columns]

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
x

# %%
y

# %%
from sklearn.preprocessing import LabelEncoder
cols = ["Sex","Profession","Marital Status",'Height',"Breathing Problem","Stress","Work Load","Food Habit","urine-color-before-meal","urine-color-after-meal","drug-history","physical-activity","headache-for-high-blood-pressure","weakness","diabetes-mellitus","Chest Pain"]
#cols=["Sex"]
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
df
# Out:
#      Sex  Age  Profession  ...  weakness  diabetes-mellitus  Chest Pain
# 0      1   35           2  ...         1                  0           0
# 1      1   60          21  ...         3                  3           1
# 2      1   37           6  ...         3                  3           1
# 3      1   29          33  ...         1                  3           1
# 4      0   35          10  ...         3                  3           0
# ..   ...  ...         ...  ...       ...                ...         ...
# 340    0   55          34  ...         3                  3           0
# 341    0   65          26  ...         3                  3           0
# 342    1   53          41  ...         3                  3           1
# 343    0   45          34  ...         3                  3           0
# 344    1   55          41  ...         3                  3           1
#
# [345 rows x 24 columns]

# %%
df.describe()
# Out:
#               Sex         Age  ...  diabetes-mellitus  Chest Pain
# count  345.000000  345.000000  ...         345.000000  345.000000
# mean     0.568116   45.284058  ...           1.701449    0.747826
# std      0.496058   14.799647  ...           1.316542    0.434891
# min      0.000000   14.000000  ...           0.000000    0.000000
# 25%      0.000000   34.000000  ...           0.000000    0.000000
# 50%      1.000000   47.000000  ...           2.000000    1.000000
# 75%      1.000000   55.000000  ...           3.000000    1.000000
# max      1.000000   86.000000  ...           3.000000    1.000000
#
# [8 rows x 24 columns]

# %%
df.corr()
# Out:
#                                        Sex  ...  Chest Pain
# Sex                               1.000000  ...    0.113541
# Age                               0.025074  ...    0.124980
# Profession                       -0.198442  ...    0.034154
# Marital Status                    0.094431  ...   -0.131840
# Height                            0.232535  ...    0.041177
# Weight(kgs)                       0.435701  ...    0.056072
# Breathing Problem                 0.088610  ...   -0.109350
# Stress                           -0.034276  ...   -0.034981
# Work Load                         0.043878  ...    0.097090
# Food Habit                       -0.067497  ...    0.032429
# heart-rate(bpm)                   0.110204  ...   -0.026298
# systolic(mmHg)                   -0.052790  ...    0.131533
# diastolic(mmHg)                  -0.056701  ...   -0.004769
# blood-sugar-before-meal(mmol/L)  -0.177229  ...    0.030891
# blood-sugar-after-meal(mmol/L)   -0.172985  ...    0.042496
# ...

# %%
corr = df.corr()
splt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True, cmap="BuPu")

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %%
# classify function
from sklearn.model_selection import cross_val_score
def classify(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
    model.fit(x_train, y_train)
    print("Accuracy is", model.score(x_test, y_test)*100)
    # cross validation - it is used for better validation of model
    # eg: cv-5, train-4, test-1
    score = cross_val_score(model, x, y, cv=10)
    print("Cross validation is",np.mean(score)*100)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics 

model = RandomForestClassifier()
classify(model, x, y)

from sklearn import metrics 
rfc=model

y_pred = rfc.predict(x_test) 
mae = round(metrics.mean_absolute_error(y_test, y_pred), 4) 
mse = round(metrics.mean_squared_error(y_test, y_pred), 4)
# Out:
# Accuracy is 82.85714285714286
# Cross validation is 73.36134453781513

# %%
mae
# Out:
# 0.1714

# %%
mse
# Out:
# 0.1714

# %%
from sklearn.svm import SVC
model = SVC()
classify(model, x, y)

from sklearn import metrics 
svm=model

y_pred = svm.predict(x_test) 
mae = round(metrics.mean_absolute_error(y_test, y_pred), 4) 
mse = round(metrics.mean_squared_error(y_test, y_pred), 4)
# Out:
# Accuracy is 82.85714285714286
# Cross validation is 74.78991596638656

# %%
mae
# Out:
# 0.1714

# %%
mse
# Out:
# 0.1714

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model, x, y)

from sklearn import metrics 
lr=model

y_pred = lr.predict(x_test) 
mae = round(metrics.mean_absolute_error(y_test, y_pred), 4) 
mse = round(metrics.mean_squared_error(y_test, y_pred), 4)
# Out:
# Accuracy is 71.42857142857143
# Cross validation is 72.52100840336134

# %%
mae
# Out:
# 0.2857

# %%
mse
# Out:
# 0.2857

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model, x, y)

from sklearn import metrics 
dt=model

y_pred = dt.predict(x_test) 
mae = round(metrics.mean_absolute_error(y_test, y_pred), 4) 
mse = round(metrics.mean_squared_error(y_test, y_pred), 4)
# Out:
# Accuracy is 62.857142857142854
# Cross validation is 61.83193277310923

# %%
mae
# Out:
# 0.3714

# %%
mse
# Out:
# 0.3714
